# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv

key = config('API_KEY')
# movieCd  movieNm  audiCnt
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&weekGb=0&targetDt='

# %%
# mov_list = []
for i in range(0,51,1):
    date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
    date2 = date1.strftime("%Y%m%d")
    data = requests.get(URL+f'{date2}').json()
    result = {}
    
    for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
#         for i in mov_list:
#             mov_list
    # data.get('boxOfficeResult').get('weeklyBoxOfficeList')
        result['movieNm'] = movie.get('movieNm')
#         if int(result['movieCd']) < int(movie.get('movieCd')):
        result['movieCd'] = movie.get('movieCd')
        result['audiCnt'] = movie.get('audiCnt')
#         mov_list.append(result)
        # 받아옴.
# print(mov_list('movieNm'))

# %%
mov_list = []
with open('boxoffice.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['Movie_code', 'Movie_Name', '관객수']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0,51,1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result = movie.get('movieNm')
            if result in mov_list:
                continue
            else:
                writer.writerow({'Movie_code': movie.get('movieCd'), 'Movie_Name': movie.get('movieNm'), '관객수': movie.get('audiCnt')})
                mov_list.append(result)
                #         for i in mov_list:
#             mov_list
    # data.get('boxOfficeResult').get('weeklyBoxOfficeList')
#         result['movieNm'] = movie.get('movieNm')
# #         if int(result['movieCd']) < int(movie.get('movieCd')):
#         result['movieCd'] = movie.get('movieCd')
#         result['audiCnt'] = movie.get('audiCnt')
#         mov_list.append(result)
        # 받아옴.
# print(mov_list('movieNm'))

# %%
print(len(mov_list))

# %%
mov_list = []
with open('boxoffice.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['movieCd', 'movieNm', 'audiCnt']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0,5,1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result['movieNm'] = movie.get('movieNm')
            if mov_list in list(result):
                continue
            else:
                writer.writerow({'movieCd': movie.get('movieNm'), 'movieNm': movie.get('movieCd'), 'audiCnt': movie.get('audiCnt')})
                mov_list.append(result)
            #         for i in mov_list:
#             mov_list
    # data.get('boxOfficeResult').get('weeklyBoxOfficeList')
#         result['movieNm'] = movie.get('movieNm')
# #         if int(result['movieCd']) < int(movie.get('movieCd')):
#         result['movieCd'] = movie.get('movieCd')
#         result['audiCnt'] = movie.get('audiCnt')
#         mov_list.append(result)
        # 받아옴.
# print(mov_list('movieNm'))

# %%
mov_list = []
with open('boxoffice.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['movieCd', 'movieNm', 'audiCnt']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0,5,1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result['movieNm'] = movie.get('movieNm')
            print(result)
            writer.writerow({'movieCd': movie.get('movieNm'), 'movieNm': movie.get('movieCd'), 'audiCnt': movie.get('audiCnt')})
#             mov_list.append(result)
            #         for i in mov_list:
#             mov_list
    # data.get('boxOfficeResult').get('weeklyBoxOfficeList')
#         result['movieNm'] = movie.get('movieNm')
# #         if int(result['movieCd']) < int(movie.get('movieCd')):
#         result['movieCd'] = movie.get('movieCd')
#         result['audiCnt'] = movie.get('audiCnt')
#         mov_list.append(result)
        # 받아옴.
# print(mov_list('movieNm'))

# %%
print()

# %%
# 파일만들기
import csv
with open('boxoffice.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['movieCd', 'movieNm', 'audiCnt']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({'movieCd': 'TEST', 'movieNm': 'AA', 'audiCnt': '25'})

# %%
# 파일만들기
import csv
with open('boxoffice.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['movieCd', 'movieNm', 'audiCnt']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({'movieCd': movie.get('movieNm'), 'movieNm': movie.get('movieCd'), 'audiCnt': movie.get('audiCnt')})

# %%
from datetime import timedelta, datetime
datetime(2015, 7, 12) - timedelta(weeks=1)

# %% [markdown]
# # 1

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv

key = config('API_KEY')
# movieCd  movieNm  audiCnt
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&weekGb=0&targetDt='
# mov_list = []
mov_list = []

with open('boxoffice.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['Movie_code', 'Movie_Name', '관객수']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0, 50, 1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}

        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result = movie.get('movieCd')
            result2 = movie.get('directors')
            if result in mov_list:
                continue
            else:
                writer.writerow({'Movie_code': movie.get('movieCd'), 'Movie_Name': movie.get('movieNm'), '관객수': movie.get('audiCnt')})
                mov_list.append(result)

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv

# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079

key = config('API_KEY')
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&weekGb=0&targetDt='

mov_list = []
with open('movie.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['대표코드', '영화명(국문)', '영화명(영문)', '영화명(원문)', '관람등급', '개봉연도', '상영시간', '장르', '감독명']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0, 5, 1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result = movie.get('movieNm')
            if result in mov_list:
                continue
            else:
                
                mov_list.append(result)
                URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
                data3 = requests.get(URL2+movie.get('movieCd')).json()
                movie2 = data3['movieInfoResult']['movieInfo']
                for movieNm in mov_list:
                    if movieNm == movie2.get('movieNm'):
                        writer.writerow({
                            '대표코드': movie2.get('movieCd'),
                            '영화명(국문)': movie2.get('movieNm'),
                            '영화명(영문)': movie2.get('movieNmEn'),
                            '영화명(원문)': movie2.get('movieNmOg'),
                            '관람등급': movie2.get('watchGradeNm'),
                            '개봉연도': movie2.get('openDt'),
                            '상영시간': movie2.get('showTm'),
                            '장르': movie2.get('genreNm'),`
                            '감독명': movie2.get('directors')
                        })

# %%
print(mov_list)

# %% [markdown]
# # 2222222

# %%
import copy
movie_info = {}
movie_info_list = []
movie_director_list = []

URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
with open('movie.csv', 'w', encoding='utf-8', newline='') as f:
        fieldnames = [
            'movieNm',
            'movieNmEn',
            'movieNmOg',
            'watchGradeNm', 
            'openDt',
            'showTm', 
            'genreNm', 
            'peopleNm'
        ]
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()

        for movie_code in mov_list:
            information = requests.get(URL2+movie_code).json().get('movieInfoResult').get('movieInfo')   
            movie_info['movieNm'] = information.get('movieNm')
            movie_info['movieNmEn'] = information.get('movieNmEn')
            movie_info['movieNmOg'] = information.get('movieNmOg')
            if information['audits']:
                movie_info['watchGradeNm'] = information.get('audits')[0].get('watchGradeNm')
            movie_info['openDt'] = information.get('openDt')
            movie_info['showTm'] = information.get('showTm')
            movie_info['genreNm'] = information.get('genres')[0].get('genreNm')
            if information['directors']:
                movie_info['peopleNm'] = information.get('directors')[0].get('peopleNm')
                movie_director_list.append(copy.copy(movie_info['peopleNm']))
            movie_info_list.append(copy.copy(movie_info))
        for i in movie_info_list:  
            writer.writerow(i)

# %%
print(movie_director_list)
# Out:
# ['존 왓츠', '가이 리치', '조시 쿨리', '남대중', '봉준호', '고정욱', '히라야마 미호', '게리 도버먼', '채드 스타헬스키', '아리 애스터', '강윤성', '로버트 페르난데스', '이정호', '닐 조단', 'F. 게리 그레이', '라스 클리브버그', '사이먼 킨버그', '미미 레더', '미야자키 하야오', '닐 버거', '덱스터 플레처', '안소니 루소']

# %% [markdown]
# # 2

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv

# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079

key = config('API_KEY')
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&weekGb=0&targetDt='
dir_list = []
mov_list = []
with open('movie.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['대표코드', '영화명(국문)', '영화명(영문)', '영화명(원문)', '관람등급', '개봉연도', '상영시간', '장르', '감독명']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0, 10, 1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result = movie.get('movieNm')
            if result in mov_list:
                continue
            else:
                mov_list.append(result)
                URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
                data3 = requests.get(URL2+movie.get('movieCd')).json()
                movie2 = data3['movieInfoResult']['movieInfo']
                dir_list.append(movie2.get('peopleNm'))
                for movieNm in mov_list:
                    if movieNm == movie2.get('movieNm'):
                        writer.writerow({
                            '대표코드': movie2.get('movieCd'),
                            '영화명(국문)': movie2.get('movieNm'),
                            '영화명(영문)': movie2.get('movieNmEn'),
                            '영화명(원문)': movie2.get('movieNmOg'),
                            '관람등급': movie2.get('watchGradeNm'),
                            '개봉연도': movie2.get('openDt'),
                            '상영시간': movie2.get('showTm'),
                            '장르': movie2.get('genreNm'),
                            '감독명': movie2.get('peopleNm')
                        })

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079
key = config('API_KEY')


URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
  

movie_info = {}
movie_info_list = []
movie_director_list = []

for movie_code in mov_list:
    information = requests.get(URL2 + movie_code).json().get('movieInfoResult').get('movieInfo')   
    movie_info['movieNm'] = information.get('movieNm')
    movie_info['movieNmEn'] = information.get('movieNmEn')
    movie_info['movieNmOg'] = information.get('movieNmOg')
    if information['audits'] :
        movie_info['watchGradeNm'] = information.get('audits')[0].get('watchGradeNm')
    movie_info['openDt'] = information.get('openDt')
    movie_info['showTm'] = information.get('showTm')
    movie_info['genreNm'] = information.get('genres')[0].get('genreNm')
    if information['directors'] :
        movie_info['peopleNm'] = information.get('directors')[0].get('peopleNm')
        movie_director_list.append(copy.copy(movie_info['peopleNm']))
    movie_info_list.append(copy.copy(movie_info))
with open('movie.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['대표코드', '영화명(국문)', '영화명(영문)', '영화명(원문)', '관람등급', '개봉연도', '상영시간', '장르', '감독명']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in movie_director_list:  
        writer.writerow(movie_director_list[i])

# %%
info_URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={API_KEY}&movieCd='
movie_info = {}
movie_info_list = []
movie_director_list = []
for movie_code in movie_codes:
   information = requests.get(info_URL + movie_code).json().get('movieInfoResult').get('movieInfo')
   movie_info['movieNm'] = information.get('movieNm')
   movie_info['movieNmEn'] = information.get('movieNmEn')
   movie_info['movieNmOg'] = information.get('movieNmOg')
   if information['audits'] :
       movie_info['watchGradeNm'] = information.get('audits')[0].get('watchGradeNm')
   movie_info['openDt'] = information.get('openDt')
   movie_info['showTm'] = information.get('showTm')
   movie_info['genreNm'] = information.get('genres')[0].get('genreNm')
   if information['directors'] :
       movie_info['peopleNm'] = information.get('directors')[0].get('peopleNm')
       movie_director_list.append(copy.copy(movie_info['peopleNm']))
   movie_info_list.append(copy.copy(movie_info))
print(movie_director_list)

# %% [markdown]
# # 3

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv
key = config('API_KEY')
with open('director.csv', 'w', encoding='utf-8', newline='') as f:
    
    fieldnames = ['영화인코드', '영화인명', '분야', '필모리스트']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for direc in dir_list:
        URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key={key}&peopleNm={direc}'
        actor_list = []
        data = requests.get(URL).json()
        result = {}
        for actor in data['peopleListResult']['peopleList']:
            if direc == actor.get('peopleNm'):
                writer.writerow({  
                    '영화인코드': actor.get('peopleCd'),
                    '영화인명': actor.get('peopleNm'),
                    '분야': actor.get('repRoleNm'),
                    '필모리스트': actor.get('filmoNames')
                })
print(movie_director_list)
# Out:
# ['존 왓츠', '가이 리치', '조시 쿨리', '남대중', '봉준호', '고정욱', '히라야마 미호', '게리 도버먼', '채드 스타헬스키', '아리 애스터', '강윤성', '로버트 페르난데스', '이정호', '닐 조단', 'F. 게리 그레이', '라스 클리브버그', '사이먼 킨버그', '미미 레더', '미야자키 하야오', '닐 버거', '덱스터 플레처', '안소니 루소']

# %%
print(movie_director_list)
# Out:
# ['존 왓츠', '가이 리치', '조시 쿨리', '남대중', '봉준호', '고정욱', '히라야마 미호', '게리 도버먼', '채드 스타헬스키', '아리 애스터', '강윤성', '로버트 페르난데스', '이정호', '닐 조단', 'F. 게리 그레이', '라스 클리브버그', '사이먼 킨버그', '미미 레더', '미야자키 하야오', '닐 버거', '덱스터 플레처', '안소니 루소']

# %%
dir_info = {}
dir_info_list = []
# URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
URL3 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key={key}&peopleNm='
# with open('director.csv', 'w', encoding='utf-8', newline='') as f:
#         fieldnames = [
#             'peopleCd',
#             'peopleNm',
#             'repRoleNm',
#             'filmoNames'
#         ]
#         writer = csv.DictWriter(f, fieldnames=fieldnames)
#         writer.writeheader()
#         for direc in movie_director_list:        
#             information2 = requests.get(URL3+direc).json().get('peopleListResult').get('peopleList')   
# #             dir_info['peopleCd'] = information2.get('peopleCd')
# #             dir_info['peopleNm'] = information2.get('peopleNm')
# #             dir_info['repRoleNm'] = information2.get('repRoleNm')
# #             dir_info['filmoNames'] = information2.get('filmoNames')
           
#             dir_info_list.append(information2)
# #             print(information2)
# #             dir_info['peopleCd'] = information2[0]
# #             dir_info['peopleNm'] = information2[1]
# #             dir_info['repRoleNm'] = information2[3]
# #             dir_info['filmoNames'] = information2[4]
#             dir_info_list.append(copy.copy(dir_info))
#         for i in dir_info_list:  
#             writer.writerow(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-03d9433774e8> in <module>
#      27             dir_info_list.append(copy.copy(dir_info))
#      28         for i in dir_info_list:
# ---> 29             writer.writerow(i)
#      30
#
# C:\Program Files\Python37\lib\csv.py in writerow(self, rowdict)
#     153
#     154     def writerow(self, rowdict):
# --> 155         return self.writer.writerow(self._dict_to_list(rowdict))
#     156
#     157     def writerows(self, rowdicts):
#
# C:\Program Files\Python37\lib\csv.py in _dict_to_list(self, rowdict)
#     146     def _dict_to_list(self, rowdict):
#     147         if self.extrasaction == "raise":
# --> 148             wrong_fields = rowdict.keys() - self.fieldnames
#     149             if wrong_fields:
#     150                 raise ValueError("dict contains fields not in fieldnames: "
#
# AttributeError: 'list' object has no attribute 'keys'

# %% [markdown]
# # 33333333333

# %%
dir_info = {}
dir_info_list = []
URL3 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key={key}&peopleNm='
actor_list = []
with open('director.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['영화인코드', '영화인명', '분야', '필모리스트']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for direc in movie_director_list: 
        data = requests.get(URL3+direc).json()
        result = {}
        for actor in data['peopleListResult']['peopleList']:
            direc = actor.get('peopleNm')

            writer.writerow({
                '영화인코드': actor.get('peopleCd'),
                '영화인명': actor.get('peopleNm'),
                '분야': actor.get('repRoleNm'),
                '필모리스트': actor.get('filmoNames')
            })

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv

# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079

key = config('API_KEY')
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&weekGb=0&targetDt='

mov_list = []
with open('movie.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['대표코드', '영화명(국문)', '영화명(영문)', '영화명(원문)', '관람등급', '개봉연도', '상영시간', '장르', '감독명']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0, 50, 1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result = movie.get('movieNm')
            if result in mov_list:
                continue
            else:
                mov_list.append(result)
                URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
                data3 = requests.get(URL2+movie.get('movieCd')).json()
                movie2 = data3['movieInfoResult']['movieInfo']
                for movieNm in mov_list:
                    if movieNm == movie2.get('movieNm'):
                        writer.writerow({
                            '대표코드': movie2.get('movieCd'),
                            '영화명(국문)': movie2.get('movieNm'),
                            '영화명(영문)': movie2.get('movieNmEn'),
                            '영화명(원문)': movie2.get('movieNmOg'),
                            '관람등급': movie2.get('watchGradeNm'),
                            '개봉연도': movie2.get('openDt'),
                            '상영시간': movie2.get('showTm'),
                            '장르': movie2.get('genreNm'),
                            '감독명': movie2.get('directors')
                        })

# %%
import requests
import csv
import datetime
from datetime import timedelta, datetime
from decouple import config

# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079

key = config('API_KEY')
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&weekGb=0&targetDt='
mov_list = []
with open('movie.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['대표코드', '영화명(국문)', '영화명(영문)', '영화명(원문)', '관람등급', '개봉연도', '상영시간', '장르', '감독명']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0, 3, 1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result = movie.get('movieNm')
            if result in mov_list:
                continue
            else:
                mov_list.append(result)
                URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
                data3 = requests.get(URL2+movie.get('movieCd')).json()
               
                if data3['movieInfoResult']['movieInfo']['audits']:
                    movie2 = data3['movieInfoResult']['movieInfo']['audits'][0]
                else:
                    movie2 = data3['movieInfoResult']['movieInfo']
                    
                for movieNm in mov_list:
                    if movieNm == movie2.get('movieNm'):
                        writer.writerow({
                            '대표코드': movie2.get('movieCd'),
                            '영화명(국문)': movie2.get('movieNm'),
                            '영화명(영문)': movie2.get('movieNmEn'),
                            '영화명(원문)': movie2.get('movieNmOg'),
                            '관람등급': movie2.get('watchGradeNm'),
                            '개봉연도': movie2.get('openDt'),
                            '상영시간': movie2.get('showTm'),
                            '장르': movie2.get('genreNm'),
                            '감독명': movie2.get('directors')
                        })

# %%
movieCd
영화 대표코드 , 영화명(국문)movieNm , 영화명(영문)movieNmEn , 영화명(원문)movieNmOg 
, 관람등급 watchGradeNm, 개봉연도 openDt, 상영시간showTm , 장genreNm
르 , 감독명 directors

# %%
영화인 코드 영화인명 분야 필모리스트

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv

# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079

key = config('API_KEY')
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key={key}'

mov_list = []
with open('movie.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['영화인코드', '영화인명', '분야', '필모리스트']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(0, 50, 1):
        date1 = datetime(2019, 7, 12) - timedelta(weeks=i)
        date2 = date1.strftime("%Y%m%d")
        data = requests.get(URL+f'{date2}').json()
        result = {}
        for movie in data['boxOfficeResult']['weeklyBoxOfficeList']:
            result = movie.get('movieNm')
            if result in mov_list:
                continue
            else:
                mov_list.append(result)    
                URL2 = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd='
                data3 = requests.get(URL2+movie.get('movieCd')).json()
                movie2 = data3['movieInfoResult']['movieInfo']
                for movieNm in mov_list:
                    if movieNm == movie2.get('movieNm'):
                        writer.writerow({
                            '대표코드': movie2.get('movieCd'),
                            '영화명(국문)': movie2.get('movieNm'),
                            '영화명(영문)': movie2.get('movieNmEn'),
                            '영화명(원문)': movie2.get('movieNmOg'),
                            '관람등급': movie2.get('watchGradeNm'),
                            '개봉연도': movie2.get('openDt'),
                            '상영시간': movie2.get('showTm'),
                            '장르': movie2.get('genreNm'),
                            '감독명': movie2.get('directors')
                        })

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv
# movie2.get('directors')
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079

direc = '안성현'
key = config('API_KEY')
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key={key}&peopleNm={direc}'

actor_list = []
with open('director.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['영화인코드', '영화인명', '분야', '필모리스트']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    data = requests.get(URL).json()
    result = {}
    for actor in data['peopleListResult']['peopleList']:
        direc = actor.get('peopleNm')
        
        writer.writerow({
            '영화인코드': actor.get('peopleCd'),
            '영화인명': actor.get('peopleNm'),
            '분야': actor.get('repRoleNm'),
            '필모리스트': actor.get('filmoNames')
        })

# %%
import requests
from decouple import config
import datetime
from datetime import timedelta, datetime
import csv

# http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079

key = config('API_KEY')
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key={key}'

actor_list = []
act
with open('director.csv', 'w', encoding='utf-8', newline='') as f:
    fieldnames = ['영화인코드', '영화인명', '분야', '필모리스트']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    data = requests.get(URL).json()
    result = {}
    for actor in data['peopleListResult']['peopleList']:
        result = actor.get('peopleNm')
        writer.writerow({
                        '영화인코드': actor.get('peopleCd'),
                        '영화인명': actor.get('peopleNm'),
                        '분야': actor.get('repRoleNm'),
                        '필모리스트': actor.get('filmoNames')
                    })
